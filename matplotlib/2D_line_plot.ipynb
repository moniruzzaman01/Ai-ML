# %%
import pandas as pd
import matplotlib.pyplot as plt
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
stdnt = [2, 3, 2.5, 4, 3, 5, 4.5]
plt.title("Study Hours Informations")
plt.xlabel("Days")
plt.ylabel("Hours")
plt.plot(days,stdnt)

# %%
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
stdnt = [2, 3, 2.5, 4, 3, 5, 4.5]
stdnt2 = [1.5, 2, 2.5, 3, 2, 3.5, 3]
stdnt3 = [3, 3.5, 4, 4.5, 4, 5, 5.5]
plt.title("Study Hours Informations")
plt.xlabel("Days")
plt.ylabel("Hours")
plt.plot(days,stdnt)
plt.plot(days,stdnt2)
plt.plot(days,stdnt3)

# %%
hours = list(range(24))
stdnt = [0, 0, 0, 0, 10, 20, 30, 45, 60, 50, 40, 30, 20, 15, 10, 25, 40, 35, 30, 20, 10, 5, 0, 0]
stdnt2 = [0, 0, 0, 0, 0, 15, 25, 40, 55, 60, 50, 40, 25, 20, 10, 15, 25, 30, 35, 25, 10, 5, 0, 0]
stdnt3 = [0, 0, 0, 0, 5, 10, 20, 30, 50, 60, 60, 50, 45, 40, 35, 30, 25, 20, 10, 5, 0, 0, 0, 0]
plt.title("Productive Time chart")
plt.xlabel("Per Hours")
plt.ylabel("Study Hours")
plt.plot(hours,stdnt)
plt.plot(hours,stdnt2)
plt.plot(hours,stdnt3)

# %%
students_info = pd.read_csv('enrollment_data.csv')
plt.title("Enrollments Over The Years")
plt.xlabel("Years")
plt.ylabel("Enrollment Number")
plt.plot(students_info['Year'],students_info['Programming'],label="Programming",color='cyan',marker='x', mec='red')
plt.plot(students_info['Year'],students_info['Digital Marketing'],label="Digital Marketing",linewidth=0.5)
plt.legend(loc='lower right') # default upper left

# %%
students_info = pd.read_csv('enrollment_data.csv')
plt.title("Enrollments Over The Years")
plt.xlabel("Years")
plt.ylabel("Enrollment Number")
plt.plot(students_info['Year'],students_info['Programming'],label="Programming",color='cyan',marker='x', mec='red')
plt.plot(students_info['Year'],students_info['Digital Marketing'],label="Digital Marketing",linewidth=0.5)
plt.legend(loc='lower right') # default upper left
plt.grid()
plt.show() # to show the graph
