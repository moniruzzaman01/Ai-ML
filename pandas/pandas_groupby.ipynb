# %%
import pandas as pd
students = pd.read_json('datas/students_info.json')
students
# Out:
#   StudentID          FullName CompletionStatus EnrollmentDate FinishingDate  \
# 0    ST1001       Alif Rahman        Completed     2024-01-10    2024-04-25
# 1    ST1002     Fatima Akhter      In Progress     2024-02-05          None
# 2    ST1003     Imran Hossain        Completed     2024-02-18    2024-06-01
# 3    ST1004  Jannatul Ferdous        Completed     2024-03-01    2024-07-10
# 4    ST1005       Kamal Uddin      In Progress     2024-04-15          None
# 5    ST1006       Laila Begum        Completed     2024-05-10    2024-09-12
# 6    ST1007    Mahmudul Hasan      Not Started     2024-07-20          None
# 7    ST1008       Nadia Islam        Completed     2024-08-01    2024-11-28
# 8    ST1009        Omar Faruq      In Progress     2024-09-18          None
# 9    ST1010      Priya Sharma        Completed     2024-10-05    2025-01-10
#
#   Instructor    Location  TotalMarks
# 0  Mr. Karim       Dhaka         258
# 1  Ms. Salma  Chattogram         184
# ...

# %%
instructos_group = students.groupby("Instructor").count()
instructos_group
# Out:
#             StudentID  FullName  CompletionStatus  EnrollmentDate  \
# Instructor
# Mr. David           2         2                 2               2
# Mr. Karim           3         3                 3               3
# Ms. Salma           5         5                 5               5
#
#             FinishingDate  Location  TotalMarks
# Instructor
# Mr. David               1         2           2
# Mr. Karim               1         3           3
# Ms. Salma               4         5           5
