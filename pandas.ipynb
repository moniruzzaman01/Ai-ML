# %% [markdown]
# # Data Read From Various Files

# %%
import pandas as pd
print('panda installed')
# Out:
# panda installed

# %% [markdown]
# From CSV File

# %%
import pandas as pd
df = pd.read_csv('datas/student_data.csv')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %% [markdown]
# From JSON File

# %%
import pandas as pd
df = pd.read_json('datas/data.json')
print(df)
print(type(df))
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                    85               85
# 1    PH1002     Fatima Akhter                    92               92
# 2    PH1004  Jannatul Ferdous                    78               78
#
#    Python Marks
# 0            88
# 1            90
# 2            82
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# From Parquet File

# %%
import pandas as pd
df = pd.read_parquet('datas/students.parquet')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
print(df.head(3))
print(df.tail(3))
df.head()
df.tail()
# Out:
#   StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001    Alif Rahman                  85.0             85.0
# 1    PH1002  Fatima Akhter                  92.0             92.0
# 2    PH1003  Imran Hossain                  88.0             88.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 17    PH1018   Babul Ahmed                  88.0             88.0
# 18    PH1019  Faria Rahman                   NaN              NaN
# 19    PH1020    Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 17          85.0        Completed     2025-09-05  Ms. Salma      Sylhet
# ...

# %%
import numpy as np
print(df.columns)
columns = np.array(df.columns)
print(columns)
# Out:
# Index(['StudentID', 'FullName', 'Data Structure Marks', 'Algorithm Marks',
#        'Python Marks', 'CompletionStatus', 'EnrollmentDate', 'Instructor',
#        'Location'],
#       dtype='object')
# ['StudentID' 'FullName' 'Data Structure Marks' 'Algorithm Marks'
#  'Python Marks' 'CompletionStatus' 'EnrollmentDate' 'Instructor'
#  'Location']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   StudentID             20 non-null     object
#  1   FullName              20 non-null     object
#  2   Data Structure Marks  16 non-null     float64
#  3   Algorithm Marks       16 non-null     float64
#  4   Python Marks          15 non-null     float64
#  5   CompletionStatus      20 non-null     object
#  6   EnrollmentDate        20 non-null     object
#  7   Instructor            20 non-null     object
#  8   Location              20 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 1.5+ KB

# %%
df.describe()
# Out:
#        Data Structure Marks  Algorithm Marks  Python Marks
# count             16.000000        16.000000     15.000000
# mean              84.000000        84.000000     85.666667
# std                6.501282         6.501282      5.394000
# min               72.000000        72.000000     76.000000
# 25%               79.500000        79.500000     83.000000
# 50%               85.500000        85.500000     85.000000
# 75%               88.250000        88.250000     88.500000
# max               94.000000        94.000000     95.000000

# %%
lst = [['shakib',26],['rakib',25],['tonmoy',26]]
lst_df = pd.DataFrame(lst,columns=['Name','Age'],index=[1,2,3])
lst_df
# Out:
#      Name  Age
# 1  shakib   26
# 2   rakib   25
# 3  tonmoy   26

# %%
tpl = (('shakib',26),('rakib',25),('tonmoy',25))
lst_df = pd.DataFrame(tpl,columns=['Name','Age'],index=[1,2,3])
lst_df
# Out:
#      Name  Age
# 1  shakib   26
# 2   rakib   25
# 3  tonmoy   25

# %%
dct = {
    'Name':['shakib','rakib','tonmoy'],
    'Age':[26,25,24]
}
dct_df = pd.DataFrame(dct,index=[1,2,3])
dct_df
# Out:
#      Name  Age
# 1  shakib   26
# 2   rakib   25
# 3  tonmoy   24

# %%
data = [
    {'Name':'Shakib','Age':26,'city':'Gazipur'},
    {'Name':'Rakib','Age':23,'city':'Rangpur'},
    {'Name':'Shakib','city':'Tangail'}
]
data_df = pd.DataFrame(data)
data_df
# Out:
#      Name   Age     city
# 0  Shakib  26.0  Gazipur
# 1   Rakib  23.0  Rangpur
# 2  Shakib   NaN  Tangail

# %%
df.loc[1:5]
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
# 5    PH1006       Laila Begum                  75.0             75.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
# 5          78.0        Completed     2024-03-08  Ms. Salma    Rajshahi

# %%
df.loc[:,["StudentID","FullName","Python Marks"]]
# Out:
#    StudentID          FullName  Python Marks
# 0     PH1001       Alif Rahman          88.0
# 1     PH1002     Fatima Akhter           NaN
# 2     PH1003     Imran Hossain          85.0
# 3     PH1004  Jannatul Ferdous          82.0
# 4     PH1005       Kamal Uddin          95.0
# 5     PH1006       Laila Begum          78.0
# 6     PH1007    Mahmudul Hasan           NaN
# 7     PH1008       Nadia Islam          85.0
# 8     PH1009        Omar Faruq          76.0
# 9     PH1010      Priya Sharma          88.0
# 10    PH1011      Rahim Sheikh          91.0
# 11    PH1012   Sadia Chowdhury          87.0
# 12    PH1013      Tanvir Ahmed          79.0
# 13    PH1014        Urmi Akter           NaN
# 14    PH1015      Wahiduzzaman          84.0
# 15    PH1016      Ziaur Rahman           NaN
# 16    PH1017       Afsana Mimi          93.0
# 17    PH1018       Babul Ahmed          85.0
# 18    PH1019      Faria Rahman           NaN
# 19    PH1020        Nasir Khan          89.0

# %%
df.loc[[0,3,4,5],["FullName","Python Marks"]]
# Out:
#            FullName  Python Marks
# 0       Alif Rahman          88.0
# 3  Jannatul Ferdous          82.0
# 4       Kamal Uddin          95.0
# 5       Laila Begum          78.0

# %%
new_df = df.set_index('StudentID')
new_df
# Out:
#                    FullName  Data Structure Marks  Algorithm Marks  \
# StudentID
# PH1001          Alif Rahman                  85.0             85.0
# PH1002        Fatima Akhter                  92.0             92.0
# PH1003        Imran Hossain                  88.0             88.0
# PH1004     Jannatul Ferdous                  78.0             78.0
# PH1005          Kamal Uddin                   NaN              NaN
# PH1006          Laila Begum                  75.0             75.0
# PH1007       Mahmudul Hasan                  80.0             80.0
# PH1008          Nadia Islam                  81.0             81.0
# PH1009           Omar Faruq                  72.0             72.0
# PH1010         Priya Sharma                  89.0             89.0
# PH1011         Rahim Sheikh                   NaN              NaN
# PH1012      Sadia Chowdhury                  85.0             85.0
# PH1013         Tanvir Ahmed                  75.0             75.0
# ...

# %%
new_df.iloc[0:2,0:3]
# Out:
#                 FullName  Data Structure Marks  Algorithm Marks
# StudentID
# PH1001       Alif Rahman                  85.0             85.0
# PH1002     Fatima Akhter                  92.0             92.0

# %%
df = pd.read_parquet('datas/students.parquet')
df.drop(0,inplace=True)
df.drop('Location', axis=1,inplace=True)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# ...

# %%
new_df.rename(columns={'FullName':"Name"},inplace=True)
new_df.iloc[2:4,3:5]
# Out:
#            Python Marks CompletionStatus
# StudentID
# PH1003             85.0        Completed
# PH1004             82.0        Completed

# %%
df = pd.read_parquet('datas/students.parquet')
df.sort_values(['Data Structure Marks','Python'],ascending=[0,0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/1b/z1j1c6vn4t7_6tmsj0nh56wr0000gn/T/ipykernel_2338/273010884.py in ?()
#       1 df = pd.read_parquet('datas/students.parquet')
# ----> 2 df.sort_values(['Data Structure Marks','Python'],ascending=[0,0])
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7190                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7191                 f" != length of by ({len(by)})"
#    7192             )
#    7193         if len(by) > 1:
# -> 7194             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7195
#    7196             # need to rewrap columns in Series to apply key function
#    7197             if key is not None:
#
# ...

# %%
not_started = df.loc[df['CompletionStatus']=='Not Started']
not_started
# Out:
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 13    PH1014    Urmi Akter                   NaN              NaN
# 18    PH1019  Faria Rahman                   NaN              NaN
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 13           NaN      Not Started     2024-07-09  Ms. Salma    Rajshahi
# 18           NaN      Not Started     2025-09-15  Mr. David  Chattogram

# %%
completed = df.loc[df['CompletionStatus']=='Completed']
completed
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
a_plus_in_python = df.loc[df['Python Marks']>80]
a_plus_in_python
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 7     PH1008       Nadia Islam                  81.0             81.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 19    PH1020        Nasir Khan                  86.0             86.0
#
# ...

# %%
lives_in_dhaka = df.loc[(df['Location']=='Dhaka') | (df['Location']=='Sylhet')]
lives_in_dhaka
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 19    PH1020        Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor Location
# ...

# %%
newdf = df.loc[df['Python Marks']>80,['Python Marks']]
newdf
# Out:
#     Python Marks
# 0           88.0
# 2           85.0
# 3           82.0
# 4           95.0
# 7           85.0
# 9           88.0
# 10          91.0
# 11          87.0
# 14          84.0
# 16          93.0
# 17          85.0
# 19          89.0

# %%
newdf = df.loc[df['Python Marks']>80,'Python Marks']=80000
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
import pandas as pd
customers = pd.read_json('datas/customers.json')
orders = pd.read_json('datas/orders.json')
print(customers)
print('-----------------------')
print(orders)
# Out:
#    id     name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4    Diana
# 4   5    Ethan
# 5   6    Fiona
# 6   7   George
# 7   8   Hannah
# 8   9      Ivy
# 9  10     Jack
# -----------------------
#     id  customerId
# 0  101           3
# 1  102           4
# 2  103           3
# 3  104           5
# 4  105           7
# 5  106           8
# 6  107           8
# 7  108          10

# %%
# pandas.merge(left, right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=None, indicator=False, validate=None)
import pandas as pd
customers = pd.read_json('datas/customers.json')
orders = pd.read_json('datas/orders.json')
joined = pd.merge(orders,customers,left_on='customerId', right_on='id', how='right')
result = joined.loc[joined['customerId'].isna(),['name']]
result = result.rename(columns={'name':"Customers Name"})
print(result)
# Out:
#    Customers Name
# 0           Alice
# 1             Bob
# 6           Fiona
# 10            Ivy

# %%
import pandas as pd
customers = pd.read_json('datas/customers.json')
customers.loc[:,'name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      Diana
# 4      Ethan
# 5      Fiona
# 6     George
# 7     Hannah
# 8        Ivy
# 9       Jack
# Name: name, dtype: object

# %%
# Out:
# 6
